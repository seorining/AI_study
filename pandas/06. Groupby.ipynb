# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sample = df.copy()
sample.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sample['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
sample['class'].apply(lambda x : '일등석' if x == 'First' else '이등석' if x == 'Second' else '삼등석').value_counts()
# Out:
# class
# 삼등석    491
# 일등석    216
# 이등석    184
# Name: count, dtype: int64

# %%
sample = df.copy()
sample
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sample.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
sample['embarked'] = sample['embarked'].apply(lambda x: 0 if x == 'Q' else 1 if x == 'S' else 2)

# %%
sample = sample.select_dtypes(include=[np.number])
sample
# Out:
#      survived  pclass   age  sibsp  parch     fare  embarked
# 0           0       3  22.0      1      0   7.2500         1
# 1           1       1  38.0      1      0  71.2833         2
# 2           1       3  26.0      0      0   7.9250         1
# 3           1       1  35.0      1      0  53.1000         1
# 4           0       3  35.0      0      0   8.0500         1
# ..        ...     ...   ...    ...    ...      ...       ...
# 886         0       2  27.0      0      0  13.0000         1
# 887         1       1  19.0      0      0  30.0000         1
# 888         0       3   NaN      1      2  23.4500         1
# 889         1       1  26.0      0      0  30.0000         2
# 890         0       3  32.0      0      0   7.7500         0
#
# [891 rows x 7 columns]

# %%
sample.groupby('embarked')[['survived']].agg(['mean', 'var'])
# Out:
#           survived
#               mean       var
# embarked
# 0         0.389610  0.240943
# 1         0.336957  0.223764
# 2         0.558824  0.247999

# %%
sample = df.copy()

# %%
# 결측치 확인
print(sample['age'].isnull().sum())
print(f"age 평균: {sample['age'].mean():.2f}")
# Out:
# 177
# age 평균: 29.70

# %%
# sample['age'] = sample.groupby('sex')['age'].apply(lambda x: x.fillna(x.mean()))

sample['age'] = sample['age'].fillna(sample['age'].isnull().mean())

# %%
# 검증코드
print(sample['age'].isnull().sum())
print(f"age 평균: {sample['age'].mean():.2f}")
# Out:
# 0
# age 평균: 23.84
